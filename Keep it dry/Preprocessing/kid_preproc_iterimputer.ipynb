# %% [markdown]
# # Keep-it-dry! Preprocessing Part 1: Imputation using IterativeImputer

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import PolynomialFeatures
from sklearn.impute import SimpleImputer
from sklearn.experimental import enable_iterative_imputer
from sklearn.impute import IterativeImputer
from sklearn.metrics import r2_score

# %% [markdown]
# ## Read Data

# %%
df = pd.read_csv('./../kid_train.csv')
df_submission = pd.read_csv('./../kid_test.csv')

# %%
df_submission.head()
# Out:
#       id product_code  loading attribute_0 attribute_1  attribute_2  \
# 0  26570            F   119.57  material_5  material_6            6
# 1  26571            F   113.51  material_5  material_6            6
# 2  26572            F   112.16  material_5  material_6            6
# 3  26573            F   112.72  material_5  material_6            6
# 4  26574            F   208.00  material_5  material_6            6
#
#    attribute_3  measurement_0  measurement_1  measurement_2  ...  \
# 0            4              6              9              6  ...
# 1            4             11              8              0  ...
# 2            4              8             12              4  ...
# 3            4              8             11             10  ...
# 4            4             14             16              8  ...
#
#    measurement_8  measurement_9  measurement_10  measurement_11  \
# 0         18.654         10.802          15.909          18.070
# 1         19.368         12.032          13.998             NaN
# 2         17.774         11.743          17.046          18.086
# 3         18.948         11.790          18.165          16.163
# 4         19.141         12.370          14.578          17.849
#
#    measurement_12  measurement_13  measurement_14  measurement_15  \
# 0          13.772          13.659          16.825          13.742
# 1          12.473          17.468          16.708          14.776
# 2          10.907          13.363          15.737          17.065
# 3          10.933          15.501          15.667          12.620
# 4          11.941          16.070          16.183          13.324
#
#    measurement_16  measurement_17
# 0          17.710         634.612
# 1          14.102         537.037
# 2          16.021         658.995
# 3          16.111         594.301
# 4          17.150         801.044
#
# [5 rows x 25 columns]

# %% [markdown]
# ### Check Data Type

# %%
df.dtypes
# Out:
# id                  int64
# product_code       object
# loading           float64
# attribute_0        object
# attribute_1        object
# attribute_2         int64
# attribute_3         int64
# measurement_0       int64
# measurement_1       int64
# measurement_2       int64
# measurement_3     float64
# measurement_4     float64
# measurement_5     float64
# measurement_6     float64
# measurement_7     float64
# measurement_8     float64
# measurement_9     float64
# measurement_10    float64
# measurement_11    float64
# measurement_12    float64
# measurement_13    float64
# measurement_14    float64
# measurement_15    float64
# measurement_16    float64
# measurement_17    float64
# failure             int64
# dtype: object

# %% [markdown]
# - Encoding needed for: product_code, attribute_0, attribute_1
# - Scaling needed for:
# loading, measurement_3, measurement_4, measurement_5, measurement_6, measurement_7, measurement_8, measurement_9, measurement_10, measurement_11, measurement_12, measurement_13, measurement_14, measurement_15, measurement_16, measurement_17

# %% [markdown]
# ### Check NaN Values

# %%
plt.figure(figsize=(10, 5))
sns.heatmap(df.isna().T, cmap='summer')
plt.title('Heatmap of missing values')
# Out:
# Text(0.5, 1.0, 'Heatmap of missing values')

# %%
df.isna().sum()
# Out:
# id                   0
# product_code         0
# loading            250
# attribute_0          0
# attribute_1          0
# attribute_2          0
# attribute_3          0
# measurement_0        0
# measurement_1        0
# measurement_2        0
# measurement_3      381
# measurement_4      538
# measurement_5      676
# measurement_6      796
# measurement_7      937
# measurement_8     1048
# measurement_9     1227
# measurement_10    1300
# measurement_11    1468
# measurement_12    1601
# measurement_13    1774
# measurement_14    1874
# measurement_15    2009
# measurement_16    2110
# measurement_17    2284
# failure              0
# dtype: int64

# %% [markdown]
# ## EDA
# - Plot: continuous features using histplot, differentiated using 'failure'.
# - Plot: categorical features using countplot, differentiated using 'failure'.

# %%
continuous_feats = df.select_dtypes(include=['float64']).columns
categorical_feats = df.select_dtypes(include=['object']).columns
nominal_feats = df.select_dtypes(include=['int64']).columns

# %%
print(nominal_feats)
# Out:
# Index(['id', 'attribute_2', 'attribute_3', 'measurement_0', 'measurement_1',
#        'measurement_2', 'failure'],
#       dtype='object')

# %% [markdown]
# ### Continuous features

# %%
fig = plt.figure(figsize=(10, 40))

for i, feat in enumerate(continuous_feats):
    ax = fig.add_subplot(8, 2, i+1)
    sns.histplot(data=df, x=feat, hue="failure", kde=True, axes=ax)
    ax.set_title(feat)

fig.tight_layout()
plt.show()
# Out:
# c:\Users\RAYHAN EGAR\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# c:\Users\RAYHAN EGAR\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# c:\Users\RAYHAN EGAR\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# c:\Users\RAYHAN EGAR\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# c:\Users\RAYHAN EGAR\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# c:\Users\RAYHAN EGAR\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# c:\Users\RAYHAN EGAR\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# c:\Users\RAYHAN EGAR\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# c:\Users\RAYHAN EGAR\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# c:\Users\RAYHAN EGAR\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# c:\Users\RAYHAN EGAR\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# c:\Users\RAYHAN EGAR\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# c:\Users\RAYHAN EGAR\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# c:\Users\RAYHAN EGAR\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# c:\Users\RAYHAN EGAR\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# c:\Users\RAYHAN EGAR\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %% [markdown]
# ### Categorical features

# %%
fig = plt.figure(figsize=(10, 10))

for i, feat in enumerate(categorical_feats):
    ax = fig.add_subplot(3, 2, i+1)
    sns.histplot(data=df, x=feat, hue="failure", axes=ax)
    ax.set_title(feat)

fig.tight_layout()
plt.show()
# Out:
# c:\Users\RAYHAN EGAR\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# c:\Users\RAYHAN EGAR\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# c:\Users\RAYHAN EGAR\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %% [markdown]
# ### Nominal features

# %%
fig = plt.figure(figsize=(10, 15))

for i, feat in enumerate(nominal_feats[1:-1]):
    ax = fig.add_subplot(3, 2, i+1)
    sns.histplot(data=df, x=feat, hue="failure", axes=ax)
    ax.set_title(feat)

fig.tight_layout()
plt.show()
# Out:
# c:\Users\RAYHAN EGAR\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# c:\Users\RAYHAN EGAR\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# c:\Users\RAYHAN EGAR\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# c:\Users\RAYHAN EGAR\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# c:\Users\RAYHAN EGAR\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %% [markdown]
# ## Imputation
# Available options:
# 1) Simple imputer, using 'mean' or 'most_frequent'
# 2) LinearRegression
# 3) Multiple LinearRegression
# 4) Polynomial Regression
# 5) Iterative Imputer

# %%
corr_matrix_cont = df[continuous_feats].corr()
sns.heatmap(corr_matrix_cont)
# Out:
# <Axes: >

# %%
corr_matrix_nominal = df[nominal_feats[1:-1]].corr()
sns.heatmap(corr_matrix_nominal, annot=True)
# Out:
# <Axes: >

# %%
df_corr_nominal = pd.DataFrame(corr_matrix_nominal)
df_corr_nominal
# Out:
#                attribute_2  attribute_3  measurement_0  measurement_1  \
# attribute_2       1.000000    -0.538697       0.175387      -0.377971
# attribute_3      -0.538697     1.000000      -0.370232       0.329233
# measurement_0     0.175387    -0.370232       1.000000      -0.255255
# measurement_1    -0.377971     0.329233      -0.255255       1.000000
# measurement_2     0.030522     0.013258      -0.083813       0.005032
#
#                measurement_2
# attribute_2         0.030522
# attribute_3         0.013258
# measurement_0      -0.083813
# measurement_1       0.005032
# measurement_2       1.000000

# %%
sns.scatterplot(data=df, x='attribute_2', y='attribute_3')
# Out:
# <Axes: xlabel='attribute_2', ylabel='attribute_3'>

# %%
df[continuous_feats].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 26570 entries, 0 to 26569
# Data columns (total 16 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   loading         26320 non-null  float64
#  1   measurement_3   26189 non-null  float64
#  2   measurement_4   26032 non-null  float64
#  3   measurement_5   25894 non-null  float64
#  4   measurement_6   25774 non-null  float64
#  5   measurement_7   25633 non-null  float64
#  6   measurement_8   25522 non-null  float64
#  7   measurement_9   25343 non-null  float64
#  8   measurement_10  25270 non-null  float64
#  9   measurement_11  25102 non-null  float64
#  10  measurement_12  24969 non-null  float64
#  11  measurement_13  24796 non-null  float64
#  12  measurement_14  24696 non-null  float64
#  13  measurement_15  24561 non-null  float64
#  14  measurement_16  24460 non-null  float64
#  15  measurement_17  24286 non-null  float64
# dtypes: float64(16)
# memory usage: 3.2 MB

# %% [markdown]
# As there's no strong linearity between features, we will proceed with IterativeImputer.

# %% [markdown]
# ### Continuous Features Imputation

# %%
df_all = pd.concat([df, df_submission], axis=0)
df_all_grouped = df_all.groupby('product_code')
df_all_grouped.head()
# Out:
#           id product_code  loading attribute_0 attribute_1  attribute_2  \
# 0          0            A    80.10  material_7  material_8            9
# 1          1            A    84.89  material_7  material_8            9
# 2          2            A    82.43  material_7  material_8            9
# 3          3            A   101.07  material_7  material_8            9
# 4          4            A   188.06  material_7  material_8            9
# 5100    5100            B    81.46  material_5  material_5            8
# 5101    5101            B    92.59  material_5  material_5            8
# 5102    5102            B   179.82  material_5  material_5            8
# 5103    5103            B   129.10  material_5  material_5            8
# 5104    5104            B   130.43  material_5  material_5            8
# 10350  10350            C   111.30  material_7  material_8            5
# 10351  10351            C   127.17  material_7  material_8            5
# 10352  10352            C    99.69  material_7  material_8            5
# 10353  10353            C   114.54  material_7  material_8            5
# 10354  10354            C   211.52  material_7  material_8            5
# 16115  16115            D    76.89  material_7  material_5            6
# 16116  16116            D    96.13  material_7  material_5            6
# 16117  16117            D   124.40  material_7  material_5            6
# 16118  16118            D   175.84  material_7  material_5            6
# 16119  16119            D   118.70  material_7  material_5            6
# 21227  21227            E   106.56  material_7  material_6            6
# 21228  21228            E   125.88  material_7  material_6            6
# 21229  21229            E   159.94  material_7  material_6            6
# 21230  21230            E   152.40  material_7  material_6            6
# 21231  21231            E   183.33  material_7  material_6            6
# 0      26570            F   119.57  material_5  material_6            6
# 1      26571            F   113.51  material_5  material_6            6
# 2      26572            F   112.16  material_5  material_6            6
# 3      26573            F   112.72  material_5  material_6            6
# 4      26574            F   208.00  material_5  material_6            6
# 5422   31992            G   164.16  material_5  material_6            9
# 5423   31993            G   164.48  material_5  material_6            9
# 5424   31994            G   112.11  material_5  material_6            9
# 5425   31995            G   124.22  material_5  material_6            9
# 5426   31996            G   103.69  material_5  material_6            9
# 10529  37099            H   152.72  material_7  material_7            7
# 10530  37100            H   134.68  material_7  material_7            7
# 10531  37101            H   147.87  material_7  material_7            7
# 10532  37102            H   110.79  material_7  material_7            7
# 10533  37103            H    81.69  material_7  material_7            7
# 15547  42117            I    90.14  material_7  material_5            9
# 15548  42118            I   138.49  material_7  material_5            9
# 15549  42119            I   126.46  material_7  material_5            9
# 15550  42120            I    89.46  material_7  material_5            9
# 15551  42121            I    79.97  material_7  material_5            9
#
#        attribute_3  measurement_0  measurement_1  measurement_2  ...  \
# 0                5              7              8              4  ...
# 1                5             14              3              3  ...
# 2                5             12              1              5  ...
# 3                5             13              2              6  ...
# 4                5              9              2              8  ...
# 5100             8             12             12              4  ...
# 5101             8              7              3              8  ...
# 5102             8              5             11             10  ...
# 5103             8              3              3              9  ...
# 5104             8             13             14             17  ...
# 10350            8              4              7              6  ...
# 10351            8              6             11              4  ...
# 10352            8              6              7              8  ...
# 10353            8             13              5              1  ...
# 10354            8              7              6              5  ...
# 16115            6             16              2              7  ...
# 16116            6              9             10              5  ...
# 16117            6             10             15              0  ...
# 16118            6              4              8             15  ...
# 16119            6             15              8              5  ...
# 21227            9              5             14              7  ...
# 21228            9              1              2             16  ...
# 21229            9              6             10             10  ...
# 21230            9              1              8              6  ...
# 21231            9              7             16              8  ...
# 0                4              6              9              6  ...
# 1                4             11              8              0  ...
# 2                4              8             12              4  ...
# 3                4              8             11             10  ...
# 4                4             14             16              8  ...
# 5422             7             11             11              4  ...
# 5423             7              8              5              4  ...
# 5424             7              6             10              2  ...
# 5425             7             15              6              6  ...
# 5426             7              4              7              5  ...
# 10529            9             12              2              3  ...
# 10530            9             12              4              3  ...
# 10531            9              7              7             16  ...
# 10532            9              5              2              0  ...
# 10533            9              8              7              4  ...
# 15547            5              1             14              6  ...
# 15548            5              5              3              9  ...
# 15549            5              0              9              8  ...
# 15550            5              0              7              7  ...
# 15551            5              3              9              3  ...
#
#        measurement_9  measurement_10  measurement_11  measurement_12  \
# 0             10.672          15.859          17.594          15.193
# 1             12.448          17.947          17.915          11.755
# 2             12.715          15.607             NaN          13.798
# 3             12.471          16.346          18.377          10.020
# 4             10.337          17.082          19.932          12.428
# 5100          12.261          14.961          18.640          11.267
# 5101          11.845          18.434          21.331          12.767
# 5102          12.171          17.084          18.645          10.618
# 5103          10.523          17.849          19.328          10.738
# 5104          12.318          16.095          22.801          11.450
# 10350         11.380          16.083             NaN          13.290
# 10351         11.912          16.257          17.474          11.300
# 10352         10.995          14.918          17.933          10.389
# 10353         10.791          17.590          16.633          11.474
# 10354         11.295          17.590          18.592          11.684
# 16115         11.536          14.690          19.622          11.082
# 16116         10.746             NaN          18.475          10.174
# 16117         10.240          16.035          18.224          11.005
# 16118         12.015          18.195          19.410          10.761
# 16119         12.615          15.775          18.778           9.683
# 21227         10.137          18.135          19.908          11.219
# 21228         12.805          18.255          20.823          10.659
# 21229          8.479          13.939          18.627          12.003
# 21230         11.845          17.015          20.150          10.950
# 21231         11.567          15.455          19.579          12.605
# 0             10.802          15.909          18.070          13.772
# 1             12.032          13.998             NaN          12.473
# 2             11.743          17.046          18.086          10.907
# 3             11.790          18.165          16.163          10.933
# 4             12.370          14.578          17.849          11.941
# 5422          10.684          13.802          20.934          13.175
# 5423          11.022          13.916          21.758          12.661
# 5424          10.471          17.118          18.755          12.354
# 5425          12.584          12.332          22.591          10.630
# 5426          11.396          17.335          18.923          12.587
# 10529         11.526          14.617          22.461          11.745
# 10530         10.249          15.043          20.237          13.125
# 10531         11.038          14.472          18.727          13.290
# 10532         11.854          13.790          18.749          13.523
# 10533            NaN          14.701          18.299           9.944
# 15547         11.187          14.079          17.960          13.269
# 15548            NaN          15.565          20.643           9.324
# 15549         10.650          17.396          17.958          14.336
# 15550         10.887          16.834          16.592          13.995
# 15551         11.181          16.289             NaN             NaN
#
#        measurement_13  measurement_14  measurement_15  measurement_16  \
# 0              15.029             NaN          13.034          14.684
# 1              14.732          15.425          14.395          15.631
# 2              16.711          18.631          14.094          17.946
# 3              15.250          15.562          16.154          17.172
# 4              16.182          12.760          13.153          16.412
# 5100           16.658          15.403          14.786          17.417
# 5101           14.080          17.255          15.344          16.296
# 5102           18.361          16.001          18.012          18.445
# 5103           18.896          17.661          15.544          16.645
# 5104           15.376          17.048          14.007             NaN
# 10350          16.202          18.518          16.589          18.701
# 10351          16.547          17.147          13.891          15.667
# 10352          15.755          16.470          16.199          14.784
# 10353          15.046          18.419             NaN          16.177
# 10354          15.717          17.500          16.392             NaN
# 16115          16.323          15.633          16.153          15.640
# 16116          15.710          16.274          12.229          17.204
# 16117          15.925          16.257          16.338          17.653
# 16118          16.176          16.926          13.813          13.615
# 16119             NaN          17.066          14.690          18.798
# 21227          15.405             NaN             NaN          15.548
# 21228          17.877             NaN          14.744          15.155
# 21229          15.298          19.076          14.972          16.820
# 21230          15.244          14.510          14.409          14.882
# 21231             NaN          15.377             NaN          16.764
# 0              13.659          16.825          13.742          17.710
# 1              17.468          16.708          14.776          14.102
# 2              13.363          15.737          17.065          16.021
# 3              15.501          15.667          12.620          16.111
# 4              16.070          16.183          13.324          17.150
# 5422           14.981          14.477          15.557          18.745
# 5423           17.167          16.799          17.238             NaN
# 5424           15.921          15.853          15.477          16.219
# 5425           15.883          14.959          14.822          19.372
# 5426           16.555          14.674          17.449          16.190
# 10529          15.901          17.957          16.414          18.487
# 10530          16.435          15.510          16.684          18.428
# 10531          16.297          17.053          13.612          17.263
# 10532          13.245          16.819          19.092          17.630
# 10533          13.865          16.379          17.569          18.991
# 15547          15.794             NaN          14.077          15.352
# 15548          16.550          18.069          15.523          18.184
# 15549          14.286             NaN          16.015          14.175
# 15550          14.773          15.962          14.391          15.798
# 15551          16.598          20.126             NaN          17.651
#
#        measurement_17  failure
# 0             764.100      0.0
# 1             682.057      0.0
# 2             663.376      0.0
# 3             826.282      0.0
# 4             579.885      0.0
# 5100          761.784      0.0
# 5101          569.667      0.0
# 5102          589.286      0.0
# 5103          646.248      0.0
# 5104          638.087      0.0
# 10350         580.378      0.0
# 10351         647.879      0.0
# 10352         715.385      0.0
# 10353             NaN      0.0
# 10354         782.793      1.0
# 16115         648.974      1.0
# 16116         741.103      0.0
# 16117             NaN      0.0
# 16118             NaN      1.0
# 16119             NaN      0.0
# 21227             NaN      0.0
# 21228         537.426      1.0
# 21229         537.094      0.0
# 21230         802.180      1.0
# 21231             NaN      0.0
# 0             634.612      NaN
# 1             537.037      NaN
# 2             658.995      NaN
# 3             594.301      NaN
# 4             801.044      NaN
# 5422          711.052      NaN
# 5423          639.068      NaN
# 5424          650.660      NaN
# 5425              NaN      NaN
# 5426          758.327      NaN
# 10529         959.147      NaN
# 10530         559.351      NaN
# 10531         713.065      NaN
# 10532         707.392      NaN
# 10533         543.207      NaN
# 15547         625.253      NaN
# 15548         733.931      NaN
# 15549         745.460      NaN
# 15550         909.593      NaN
# 15551             NaN      NaN
#
# [45 rows x 26 columns]

# %%
df_all.shape
# Out:
# (47345, 26)

# %%
# Separate ID
df_ids = set(df['id'])
df_submission_ids = set(df_submission['id'])
print("df_ids: ", len(df_ids))
print("df_submission_ids: ", len(df_submission_ids))
# Out:
# df_ids:  26570
# df_submission_ids:  20775

# %%
imputed_df = df_all.copy()

for group_name, group_df in df_all_grouped:
    # Drop 'product_code'
    df_curr = group_df[continuous_feats]
    # Initialize imputer
    imputer = IterativeImputer()
    # Fit and transform for current group
    imputer.fit(df_curr)
    imputed_df.loc[imputed_df['product_code']==group_name, continuous_feats] = imputer.transform(imputed_df.loc[imputed_df['product_code']==group_name, continuous_feats])

# %%
imputed_df.shape
# Out:
# (47345, 26)

# %%
imputed_df.isna().sum()
# Out:
# id                    0
# product_code          0
# loading               0
# attribute_0           0
# attribute_1           0
# attribute_2           0
# attribute_3           0
# measurement_0         0
# measurement_1         0
# measurement_2         0
# measurement_3         0
# measurement_4         0
# measurement_5         0
# measurement_6         0
# measurement_7         0
# measurement_8         0
# measurement_9         0
# measurement_10        0
# measurement_11        0
# measurement_12        0
# measurement_13        0
# measurement_14        0
# measurement_15        0
# measurement_16        0
# measurement_17        0
# failure           20775
# dtype: int64

# %%
df = imputed_df[imputed_df['id'].isin(df_ids)]

# %%
df_submission = imputed_df[imputed_df['id'].isin(df_submission_ids)]
df_submission.drop('failure', axis=1, inplace=True)
# Out:
# C:\Users\RAYHAN EGAR\AppData\Local\Temp\ipykernel_38724\75855262.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_submission.drop('failure', axis=1, inplace=True)

# %%
df.shape
# Out:
# (26570, 26)

# %%
plt.figure(figsize=(10, 5))
sns.heatmap(df.isna().T, cmap='summer')
plt.title('Heatmap of missing values after IterativeImputer')
# Out:
# Text(0.5, 1.0, 'Heatmap of missing values after IterativeImputer')

# %%
plt.figure(figsize=(10, 5))
sns.heatmap(df_submission.isna().T, cmap='summer')
plt.title('Heatmap of missing values (Submission Test) after IterativeImputer')
# Out:
# Text(0.5, 1.0, 'Heatmap of missing values (Submission Test) after IterativeImputer')

# %%
df.to_csv('kid_train_iterimp.csv')
df_submission.to_csv('kid_test_iterimp.csv')
