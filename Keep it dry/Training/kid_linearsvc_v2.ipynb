# %% [markdown]
# # Keep-it-dry! LinearSVC v2 Optimization with Optuna
# Dataset: ki_ro_ros.csv

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import optuna
# from sklearnex import patch_sklearn

from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import f1_score
from sklearn.metrics import roc_auc_score
from sklearn.pipeline import make_pipeline
from sklearn.svm import LinearSVC
from sklearn.decomposition import PCA

from pprint import pprint

# %% [markdown]
# ## Data Read

# %%
df_train = pd.read_csv('./../Preprocessing/kid_train_ki_ro_ros.csv', index_col=0)
df_test = pd.read_csv('./../Preprocessing/kid_test_ki_ro.csv', index_col=0)

# %%
df_train.head()
# Out:
#     loading  attribute_0  attribute_1  attribute_2  attribute_3  \
# 0 -0.866789          7.0          8.0            9            5
# 1 -0.768774          7.0          8.0            9            5
# 2 -0.819112          7.0          8.0            9            5
# 3 -0.437692          7.0          8.0            9            5
# 4  1.342337          7.0          8.0            9            5
#
#    measurement_0  measurement_1  measurement_2  measurement_3  measurement_4  \
# 0       0.000000       0.000000          -0.50       0.191386       0.587838
# 1       1.166667      -0.833333          -0.75       0.320974      -0.146396
# 2       0.833333      -1.166667          -0.25       0.204120      -0.062312
# 3       1.000000      -1.000000           0.00      -0.366667      -0.410661
# 4       0.333333      -1.000000           0.50       1.169663       0.912162
#
#    ...  measurement_9  measurement_10  measurement_11  measurement_12  \
# 0  ...      -0.582308       -0.155224       -0.823018        1.817328
# 1  ...       0.783846        1.031983       -0.658824        0.022965
# 2  ...       0.989231       -0.298507       -0.298414        1.089248
# 3  ...       0.801538        0.121677       -0.422506       -0.882568
# 4  ...      -0.840000        0.540156        0.372890        0.374217
#
#    measurement_13  measurement_14  measurement_15  measurement_16  \
# 0       -0.416608       -0.826421       -0.996926       -0.798281
# 1       -0.627395       -0.310259       -0.299693       -0.369968
# 2        0.777147        1.355888       -0.453893        0.677069
# 3       -0.259759       -0.239060        0.601434        0.327001
# 4        0.401703       -1.695250       -0.935963       -0.016735
#
#    measurement_17  failure
# 0        0.405153      0.0
# 1       -0.127292      0.0
# 2       -0.248529      0.0
# 3        0.808704      0.0
# 4       -0.790371      0.0
#
# [5 rows x 24 columns]

# %%
df_test_id = df_test[['id']]
df_test.drop(columns=['id', 'product_code', 'product_code_F', 'product_code_G', 'product_code_H', 'product_code_I'], inplace=True)
df_test.head()
# Out:
#     loading  attribute_0  attribute_1  attribute_2  attribute_3  \
# 0 -0.059136          5.0          6.0            6            4
# 1 -0.183139          5.0          6.0            6            4
# 2 -0.210763          5.0          6.0            6            4
# 3 -0.199304          5.0          6.0            6            4
# 4  1.750358          5.0          6.0            6            4
#
#    measurement_0  measurement_1  measurement_2  measurement_3  measurement_4  \
# 0      -0.166667       0.166667            0.0       1.138951      -1.168919
# 1       0.666667       0.000000           -1.5       0.073783       0.144144
# 2       0.166667       0.666667           -0.5       0.517228      -0.941441
# 3       0.166667       0.500000            1.0      -0.948689      -0.635886
# 4       1.166667       1.333333            0.5       0.017603       0.719219
#
#    ...  measurement_8  measurement_9  measurement_10  measurement_11  \
# 0  ...      -0.274792      -0.482308       -0.126795       -0.579540
# 1  ...       0.265708       0.463846       -1.213362       -0.441432
# 2  ...      -0.940954       0.241538        0.519687       -0.571355
# 3  ...      -0.052233       0.277692        1.155935       -1.554987
# 4  ...       0.093868       0.723846       -0.883582       -0.692583
#
#    measurement_12  measurement_13  measurement_14  measurement_15  \
# 0        1.075678       -1.388928        0.417316       -0.634221
# 1        0.397704        1.314407        0.356512       -0.104508
# 2       -0.419624       -1.599006       -0.148114        1.068135
# 3       -0.406054       -0.081618       -0.184492       -1.209016
# 4        0.120042        0.322214        0.083671       -0.848361
#
#    measurement_16  measurement_17
# 0        0.570330       -0.435202
# 1       -1.061511       -1.068447
# 2       -0.193578       -0.276961
# 3       -0.152872       -0.696814
# 4        0.317051        0.644913
#
# [5 rows x 23 columns]

# %%
# Scale
# Scaled already

# %%
X_df = df_train[df_train.columns[:-1]]
y_df = df_train[df_train.columns[-1]]

# %% [markdown]
# ## PCA

# %%
n_components_range = range(10, 23)  # Explore components from 10 to 22

best_n_components = None
best_score = -np.inf  # Initialize with a negative infinity

for n_components in n_components_range:
  # Apply PCA with current n_components
  pca = PCA(n_components=n_components)
  pca_data = pca.fit_transform(X_df)

  # Train linearsvc on transformed data
  model = LinearSVC()
  model.fit(pca_data, y_df)

  # Evaluate performance on testing set (e.g., using F1 score)
  score = model.score(pca.transform(X_df), y_df)
  print(f"{n_components} components score: {score}")

  # Update best component and score if performance improves
  if score > best_score:
    best_n_components = n_components
    best_score = score

print("Best number of components based on LinearSVC performance:", best_n_components)
# Out:
# /home/sobaqov/anaconda3/lib/python3.11/site-packages/sklearn/svm/_classes.py:31: FutureWarning: The default value of `dual` will change from `True` to `'auto'` in 1.5. Set the value of `dual` explicitly to suppress the warning.
#   warnings.warn(
# /home/sobaqov/anaconda3/lib/python3.11/site-packages/sklearn/svm/_base.py:1237: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /home/sobaqov/anaconda3/lib/python3.11/site-packages/sklearn/svm/_classes.py:31: FutureWarning: The default value of `dual` will change from `True` to `'auto'` in 1.5. Set the value of `dual` explicitly to suppress the warning.
#   warnings.warn(
# 10 components score: 0.5628077051766168
# /home/sobaqov/anaconda3/lib/python3.11/site-packages/sklearn/svm/_base.py:1237: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /home/sobaqov/anaconda3/lib/python3.11/site-packages/sklearn/svm/_classes.py:31: FutureWarning: The default value of `dual` will change from `True` to `'auto'` in 1.5. Set the value of `dual` explicitly to suppress the warning.
#   warnings.warn(
# 11 components score: 0.5647196596720998
# /home/sobaqov/anaconda3/lib/python3.11/site-packages/sklearn/svm/_base.py:1237: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /home/sobaqov/anaconda3/lib/python3.11/site-packages/sklearn/svm/_classes.py:31: FutureWarning: The default value of `dual` will change from `True` to `'auto'` in 1.5. Set the value of `dual` explicitly to suppress the warning.
#   warnings.warn(
# 12 components score: 0.5647913579656804
# /home/sobaqov/anaconda3/lib/python3.11/site-packages/sklearn/svm/_base.py:1237: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /home/sobaqov/anaconda3/lib/python3.11/site-packages/sklearn/svm/_classes.py:31: FutureWarning: The default value of `dual` will change from `True` to `'auto'` in 1.5. Set the value of `dual` explicitly to suppress the warning.
#   warnings.warn(
# 13 components score: 0.5638353807179389
# /home/sobaqov/anaconda3/lib/python3.11/site-packages/sklearn/svm/_base.py:1237: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /home/sobaqov/anaconda3/lib/python3.11/site-packages/sklearn/svm/_classes.py:31: FutureWarning: The default value of `dual` will change from `True` to `'auto'` in 1.5. Set the value of `dual` explicitly to suppress the warning.
#   warnings.warn(
# 14 components score: 0.5634529898188423
# /home/sobaqov/anaconda3/lib/python3.11/site-packages/sklearn/svm/_base.py:1237: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /home/sobaqov/anaconda3/lib/python3.11/site-packages/sklearn/svm/_classes.py:31: FutureWarning: The default value of `dual` will change from `True` to `'auto'` in 1.5. Set the value of `dual` explicitly to suppress the warning.
#   warnings.warn(
# 15 components score: 0.563213995506907
# /home/sobaqov/anaconda3/lib/python3.11/site-packages/sklearn/svm/_base.py:1237: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /home/sobaqov/anaconda3/lib/python3.11/site-packages/sklearn/svm/_classes.py:31: FutureWarning: The default value of `dual` will change from `True` to `'auto'` in 1.5. Set the value of `dual` explicitly to suppress the warning.
#   warnings.warn(
# 16 components score: 0.5672052005162277
# /home/sobaqov/anaconda3/lib/python3.11/site-packages/sklearn/svm/_base.py:1237: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /home/sobaqov/anaconda3/lib/python3.11/site-packages/sklearn/svm/_classes.py:31: FutureWarning: The default value of `dual` will change from `True` to `'auto'` in 1.5. Set the value of `dual` explicitly to suppress the warning.
#   warnings.warn(
# 17 components score: 0.5668228096171312
# /home/sobaqov/anaconda3/lib/python3.11/site-packages/sklearn/svm/_base.py:1237: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /home/sobaqov/anaconda3/lib/python3.11/site-packages/sklearn/svm/_classes.py:31: FutureWarning: The default value of `dual` will change from `True` to `'auto'` in 1.5. Set the value of `dual` explicitly to suppress the warning.
#   warnings.warn(
# 18 components score: 0.5665360164428087
# /home/sobaqov/anaconda3/lib/python3.11/site-packages/sklearn/svm/_base.py:1237: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /home/sobaqov/anaconda3/lib/python3.11/site-packages/sklearn/svm/_classes.py:31: FutureWarning: The default value of `dual` will change from `True` to `'auto'` in 1.5. Set the value of `dual` explicitly to suppress the warning.
#   warnings.warn(
# 19 components score: 0.5660819272501314
# /home/sobaqov/anaconda3/lib/python3.11/site-packages/sklearn/svm/_base.py:1237: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /home/sobaqov/anaconda3/lib/python3.11/site-packages/sklearn/svm/_classes.py:31: FutureWarning: The default value of `dual` will change from `True` to `'auto'` in 1.5. Set the value of `dual` explicitly to suppress the warning.
#   warnings.warn(
# 20 components score: 0.5661775249749056
# /home/sobaqov/anaconda3/lib/python3.11/site-packages/sklearn/svm/_base.py:1237: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /home/sobaqov/anaconda3/lib/python3.11/site-packages/sklearn/svm/_classes.py:31: FutureWarning: The default value of `dual` will change from `True` to `'auto'` in 1.5. Set the value of `dual` explicitly to suppress the warning.
#   warnings.warn(
# 21 components score: 0.566775010754744
# 22 components score: 0.5650781511400028
# Best number of components based on LinearSVC performance: 16
# /home/sobaqov/anaconda3/lib/python3.11/site-packages/sklearn/svm/_base.py:1237: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(

# %%
pca = PCA(n_components=16)
X_df_pca = pca.fit_transform(X_df)
df_test_pca = pca.transform(df_test)

# %% [markdown]
# ## Hyperparameter Tuning using Optuna

# %%
X_train, X_val, y_train, y_val = train_test_split(X_df_pca, y_df, test_size=.75, random_state=42, stratify=y_df)

# %%
# Define model objective function
def objective(trial):
    penalty = trial.suggest_categorical("penalty", ["l2"])
    loss = trial.suggest_categorical("loss", ["squared_hinge", "hinge"])
    C = trial.suggest_loguniform("C", 1e-3, 1e3)

    model = LinearSVC()
    model.fit(X_train, y_train)

    y_pred = model.predict(X_val)
    score = f1_score(y_val, y_pred)
    return score

# Create Optuna study
study = optuna.create_study(direction='maximize')
study.optimize(objective, n_trials=100)

best_params = study.best_params
best_model = LinearSVC(**best_params)

print("Best parameters: ", best_params)
print("Best model: ", best_model)
# Out:
# [I 2024-05-12 22:35:20,123] A new study created in memory with name: no-name-d9849ce0-9426-4739-8270-acf3f674ccc2
# /tmp/ipykernel_46479/1555980142.py:5: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform("C", 1e-3, 1e3)
# /home/sobaqov/anaconda3/lib/python3.11/site-packages/sklearn/svm/_classes.py:31: FutureWarning: The default value of `dual` will change from `True` to `'auto'` in 1.5. Set the value of `dual` explicitly to suppress the warning.
#   warnings.warn(
# [I 2024-05-12 22:35:20,564] Trial 0 finished with value: 0.5398517922408879 and parameters: {'penalty': 'l2', 'loss': 'hinge', 'C': 0.0038878058341907922}. Best is trial 0 with value: 0.5398517922408879.
# /tmp/ipykernel_46479/1555980142.py:5: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform("C", 1e-3, 1e3)
# /home/sobaqov/anaconda3/lib/python3.11/site-packages/sklearn/svm/_classes.py:31: FutureWarning: The default value of `dual` will change from `True` to `'auto'` in 1.5. Set the value of `dual` explicitly to suppress the warning.
#   warnings.warn(
# [I 2024-05-12 22:35:21,041] Trial 1 finished with value: 0.5398517922408879 and parameters: {'penalty': 'l2', 'loss': 'hinge', 'C': 0.011893763808013526}. Best is trial 0 with value: 0.5398517922408879.
# /tmp/ipykernel_46479/1555980142.py:5: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform("C", 1e-3, 1e3)
# /home/sobaqov/anaconda3/lib/python3.11/site-packages/sklearn/svm/_classes.py:31: FutureWarning: The default value of `dual` will change from `True` to `'auto'` in 1.5. Set the value of `dual` explicitly to suppress the warning.
#   warnings.warn(
# /home/sobaqov/anaconda3/lib/python3.11/site-packages/sklearn/svm/_base.py:1237: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# [I 2024-05-12 22:35:21,609] Trial 2 finished with value: 0.5398517922408879 and parameters: {'penalty': 'l2', 'loss': 'squared_hinge', 'C': 22.168525109923703}. Best is trial 0 with value: 0.5398517922408879.
# /tmp/ipykernel_46479/1555980142.py:5: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform("C", 1e-3, 1e3)
# /home/sobaqov/anaconda3/lib/python3.11/site-packages/sklearn/svm/_classes.py:31: FutureWarning: The default value of `dual` will change from `True` to `'auto'` in 1.5. Set the value of `dual` explicitly to suppress the warning.
#   warnings.warn(
# /home/sobaqov/anaconda3/lib/python3.11/site-packages/sklearn/svm/_base.py:1237: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# [I 2024-05-12 22:35:22,130] Trial 3 finished with value: 0.5398336909871244 and parameters: {'penalty': 'l2', 'loss': 'hinge', 'C': 1.6242751257826358}. Best is trial 0 with value: 0.5398517922408879.
# /tmp/ipykernel_46479/1555980142.py:5: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform("C", 1e-3, 1e3)
# /home/sobaqov/anaconda3/lib/python3.11/site-packages/sklearn/svm/_classes.py:31: FutureWarning: The default value of `dual` will change from `True` to `'auto'` in 1.5. Set the value of `dual` explicitly to suppress the warning.
#   warnings.warn(
# [I 2024-05-12 22:35:22,591] Trial 4 finished with value: 0.5398517922408879 and parameters: {'penalty': 'l2', 'loss': 'hinge', 'C': 3.0714134431761764}. Best is trial 0 with value: 0.5398517922408879.
# /tmp/ipykernel_46479/1555980142.py:5: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform("C", 1e-3, 1e3)
# /home/sobaqov/anaconda3/lib/python3.11/site-packages/sklearn/svm/_classes.py:31: FutureWarning: The default value of `dual` will change from `True` to `'auto'` in 1.5. Set the value of `dual` explicitly to suppress the warning.
#   warnings.warn(
# [I 2024-05-12 22:35:23,043] Trial 5 finished with value: 0.5398517922408879 and parameters: {'penalty': 'l2', 'loss': 'squared_hinge', 'C': 0.0062969906579764204}. Best is trial 0 with value: 0.5398517922408879.
# /tmp/ipykernel_46479/1555980142.py:5: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform("C", 1e-3, 1e3)
# /home/sobaqov/anaconda3/lib/python3.11/site-packages/sklearn/svm/_classes.py:31: FutureWarning: The default value of `dual` will change from `True` to `'auto'` in 1.5. Set the value of `dual` explicitly to suppress the warning.
#   warnings.warn(
# [I 2024-05-12 22:35:23,469] Trial 6 finished with value: 0.5398517922408879 and parameters: {'penalty': 'l2', 'loss': 'hinge', 'C': 1.3142910909711794}. Best is trial 0 with value: 0.5398517922408879.
# /tmp/ipykernel_46479/1555980142.py:5: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform("C", 1e-3, 1e3)
# /home/sobaqov/anaconda3/lib/python3.11/site-packages/sklearn/svm/_classes.py:31: FutureWarning: The default value of `dual` will change from `True` to `'auto'` in 1.5. Set the value of `dual` explicitly to suppress the warning.
#   warnings.warn(
# [I 2024-05-12 22:35:23,890] Trial 7 finished with value: 0.5398517922408879 and parameters: {'penalty': 'l2', 'loss': 'hinge', 'C': 455.3934939041423}. Best is trial 0 with value: 0.5398517922408879.
# /tmp/ipykernel_46479/1555980142.py:5: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform("C", 1e-3, 1e3)
# /home/sobaqov/anaconda3/lib/python3.11/site-packages/sklearn/svm/_classes.py:31: FutureWarning: The default value of `dual` will change from `True` to `'auto'` in 1.5. Set the value of `dual` explicitly to suppress the warning.
#   warnings.warn(
# [I 2024-05-12 22:35:24,326] Trial 8 finished with value: 0.5398517922408879 and parameters: {'penalty': 'l2', 'loss': 'squared_hinge', 'C': 0.925644766667528}. Best is trial 0 with value: 0.5398517922408879.
# /tmp/ipykernel_46479/1555980142.py:5: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform("C", 1e-3, 1e3)
# /home/sobaqov/anaconda3/lib/python3.11/site-packages/sklearn/svm/_classes.py:31: FutureWarning: The default value of `dual` will change from `True` to `'auto'` in 1.5. Set the value of `dual` explicitly to suppress the warning.
#   warnings.warn(
# [I 2024-05-12 22:35:24,785] Trial 9 finished with value: 0.5398517922408879 and parameters: {'penalty': 'l2', 'loss': 'hinge', 'C': 68.23953651362507}. Best is trial 0 with value: 0.5398517922408879.
# /tmp/ipykernel_46479/1555980142.py:5: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform("C", 1e-3, 1e3)
# /home/sobaqov/anaconda3/lib/python3.11/site-packages/sklearn/svm/_classes.py:31: FutureWarning: The default value of `dual` will change from `True` to `'auto'` in 1.5. Set the value of `dual` explicitly to suppress the warning.
#   warnings.warn(
# [I 2024-05-12 22:35:25,243] Trial 10 finished with value: 0.5398517922408879 and parameters: {'penalty': 'l2', 'loss': 'squared_hinge', 'C': 0.0012471768501257433}. Best is trial 0 with value: 0.5398517922408879.
# /tmp/ipykernel_46479/1555980142.py:5: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform("C", 1e-3, 1e3)
# /home/sobaqov/anaconda3/lib/python3.11/site-packages/sklearn/svm/_classes.py:31: FutureWarning: The default value of `dual` will change from `True` to `'auto'` in 1.5. Set the value of `dual` explicitly to suppress the warning.
#   warnings.warn(
# [I 2024-05-12 22:35:25,709] Trial 11 finished with value: 0.5398517922408879 and parameters: {'penalty': 'l2', 'loss': 'hinge', 'C': 0.04031835079336014}. Best is trial 0 with value: 0.5398517922408879.
# /tmp/ipykernel_46479/1555980142.py:5: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform("C", 1e-3, 1e3)
# /home/sobaqov/anaconda3/lib/python3.11/site-packages/sklearn/svm/_classes.py:31: FutureWarning: The default value of `dual` will change from `True` to `'auto'` in 1.5. Set the value of `dual` explicitly to suppress the warning.
#   warnings.warn(
# [I 2024-05-12 22:35:26,189] Trial 12 finished with value: 0.5398517922408879 and parameters: {'penalty': 'l2', 'loss': 'hinge', 'C': 0.04940536670422007}. Best is trial 0 with value: 0.5398517922408879.
# /tmp/ipykernel_46479/1555980142.py:5: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform("C", 1e-3, 1e3)
# /home/sobaqov/anaconda3/lib/python3.11/site-packages/sklearn/svm/_classes.py:31: FutureWarning: The default value of `dual` will change from `True` to `'auto'` in 1.5. Set the value of `dual` explicitly to suppress the warning.
#   warnings.warn(
# /home/sobaqov/anaconda3/lib/python3.11/site-packages/sklearn/svm/_base.py:1237: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# [I 2024-05-12 22:35:26,753] Trial 13 finished with value: 0.5398571380663335 and parameters: {'penalty': 'l2', 'loss': 'hinge', 'C': 0.03381998185356478}. Best is trial 13 with value: 0.5398571380663335.
# /tmp/ipykernel_46479/1555980142.py:5: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform("C", 1e-3, 1e3)
# /home/sobaqov/anaconda3/lib/python3.11/site-packages/sklearn/svm/_classes.py:31: FutureWarning: The default value of `dual` will change from `True` to `'auto'` in 1.5. Set the value of `dual` explicitly to suppress the warning.
#   warnings.warn(
# /home/sobaqov/anaconda3/lib/python3.11/site-packages/sklearn/svm/_base.py:1237: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# [I 2024-05-12 22:35:27,383] Trial 14 finished with value: 0.5398517922408879 and parameters: {'penalty': 'l2', 'loss': 'hinge', 'C': 0.17170010672868916}. Best is trial 13 with value: 0.5398571380663335.
# /tmp/ipykernel_46479/1555980142.py:5: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform("C", 1e-3, 1e3)
# /home/sobaqov/anaconda3/lib/python3.11/site-packages/sklearn/svm/_classes.py:31: FutureWarning: The default value of `dual` will change from `True` to `'auto'` in 1.5. Set the value of `dual` explicitly to suppress the warning.
#   warnings.warn(
# [I 2024-05-12 22:35:27,883] Trial 15 finished with value: 0.5398517922408879 and parameters: {'penalty': 'l2', 'loss': 'hinge', 'C': 0.001199514203684633}. Best is trial 13 with value: 0.5398571380663335.
# /tmp/ipykernel_46479/1555980142.py:5: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform("C", 1e-3, 1e3)
# /home/sobaqov/anaconda3/lib/python3.11/site-packages/sklearn/svm/_classes.py:31: FutureWarning: The default value of `dual` will change from `True` to `'auto'` in 1.5. Set the value of `dual` explicitly to suppress the warning.
#   warnings.warn(
# /home/sobaqov/anaconda3/lib/python3.11/site-packages/sklearn/svm/_base.py:1237: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# [I 2024-05-12 22:35:28,452] Trial 16 finished with value: 0.5398517922408879 and parameters: {'penalty': 'l2', 'loss': 'hinge', 'C': 0.007735180298176983}. Best is trial 13 with value: 0.5398571380663335.
# /tmp/ipykernel_46479/1555980142.py:5: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform("C", 1e-3, 1e3)
# /home/sobaqov/anaconda3/lib/python3.11/site-packages/sklearn/svm/_classes.py:31: FutureWarning: The default value of `dual` will change from `True` to `'auto'` in 1.5. Set the value of `dual` explicitly to suppress the warning.
#   warnings.warn(
# [I 2024-05-12 22:35:28,885] Trial 17 finished with value: 0.5398517922408879 and parameters: {'penalty': 'l2', 'loss': 'hinge', 'C': 0.2204753070868024}. Best is trial 13 with value: 0.5398571380663335.
# /tmp/ipykernel_46479/1555980142.py:5: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform("C", 1e-3, 1e3)
# /home/sobaqov/anaconda3/lib/python3.11/site-packages/sklearn/svm/_classes.py:31: FutureWarning: The default value of `dual` will change from `True` to `'auto'` in 1.5. Set the value of `dual` explicitly to suppress the warning.
#   warnings.warn(
# [I 2024-05-12 22:35:29,317] Trial 18 finished with value: 0.5398517922408879 and parameters: {'penalty': 'l2', 'loss': 'squared_hinge', 'C': 0.053474586755700396}. Best is trial 13 with value: 0.5398571380663335.
# /tmp/ipykernel_46479/1555980142.py:5: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform("C", 1e-3, 1e3)
# /home/sobaqov/anaconda3/lib/python3.11/site-packages/sklearn/svm/_classes.py:31: FutureWarning: The default value of `dual` will change from `True` to `'auto'` in 1.5. Set the value of `dual` explicitly to suppress the warning.
#   warnings.warn(
# [I 2024-05-12 22:35:29,769] Trial 19 finished with value: 0.5398517922408879 and parameters: {'penalty': 'l2', 'loss': 'hinge', 'C': 0.004012855805171337}. Best is trial 13 with value: 0.5398571380663335.
# /tmp/ipykernel_46479/1555980142.py:5: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform("C", 1e-3, 1e3)
# /home/sobaqov/anaconda3/lib/python3.11/site-packages/sklearn/svm/_classes.py:31: FutureWarning: The default value of `dual` will change from `True` to `'auto'` in 1.5. Set the value of `dual` explicitly to suppress the warning.
#   warnings.warn(
# /home/sobaqov/anaconda3/lib/python3.11/site-packages/sklearn/svm/_base.py:1237: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# [I 2024-05-12 22:35:30,281] Trial 20 finished with value: 0.5398517922408879 and parameters: {'penalty': 'l2', 'loss': 'hinge', 'C': 0.20772763151707738}. Best is trial 13 with value: 0.5398571380663335.
# /tmp/ipykernel_46479/1555980142.py:5: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform("C", 1e-3, 1e3)
# /home/sobaqov/anaconda3/lib/python3.11/site-packages/sklearn/svm/_classes.py:31: FutureWarning: The default value of `dual` will change from `True` to `'auto'` in 1.5. Set the value of `dual` explicitly to suppress the warning.
#   warnings.warn(
# [I 2024-05-12 22:35:30,706] Trial 21 finished with value: 0.5398517922408879 and parameters: {'penalty': 'l2', 'loss': 'hinge', 'C': 0.01613265563824682}. Best is trial 13 with value: 0.5398571380663335.
# /tmp/ipykernel_46479/1555980142.py:5: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform("C", 1e-3, 1e3)
# /home/sobaqov/anaconda3/lib/python3.11/site-packages/sklearn/svm/_classes.py:31: FutureWarning: The default value of `dual` will change from `True` to `'auto'` in 1.5. Set the value of `dual` explicitly to suppress the warning.
#   warnings.warn(
# [I 2024-05-12 22:35:31,189] Trial 22 finished with value: 0.5398517922408879 and parameters: {'penalty': 'l2', 'loss': 'hinge', 'C': 0.015742702027564236}. Best is trial 13 with value: 0.5398571380663335.
# /tmp/ipykernel_46479/1555980142.py:5: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform("C", 1e-3, 1e3)
# /home/sobaqov/anaconda3/lib/python3.11/site-packages/sklearn/svm/_classes.py:31: FutureWarning: The default value of `dual` will change from `True` to `'auto'` in 1.5. Set the value of `dual` explicitly to suppress the warning.
#   warnings.warn(
# /home/sobaqov/anaconda3/lib/python3.11/site-packages/sklearn/svm/_base.py:1237: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# [I 2024-05-12 22:35:31,759] Trial 23 finished with value: 0.5398336909871244 and parameters: {'penalty': 'l2', 'loss': 'hinge', 'C': 0.0042087465027852815}. Best is trial 13 with value: 0.5398571380663335.
# /tmp/ipykernel_46479/1555980142.py:5: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform("C", 1e-3, 1e3)
# /home/sobaqov/anaconda3/lib/python3.11/site-packages/sklearn/svm/_classes.py:31: FutureWarning: The default value of `dual` will change from `True` to `'auto'` in 1.5. Set the value of `dual` explicitly to suppress the warning.
#   warnings.warn(
# [I 2024-05-12 22:35:32,213] Trial 24 finished with value: 0.5398517922408879 and parameters: {'penalty': 'l2', 'loss': 'hinge', 'C': 0.0021515710334892415}. Best is trial 13 with value: 0.5398571380663335.
# /tmp/ipykernel_46479/1555980142.py:5: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform("C", 1e-3, 1e3)
# /home/sobaqov/anaconda3/lib/python3.11/site-packages/sklearn/svm/_classes.py:31: FutureWarning: The default value of `dual` will change from `True` to `'auto'` in 1.5. Set the value of `dual` explicitly to suppress the warning.
#   warnings.warn(
# /home/sobaqov/anaconda3/lib/python3.11/site-packages/sklearn/svm/_base.py:1237: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# [I 2024-05-12 22:35:32,739] Trial 25 finished with value: 0.5398390342052314 and parameters: {'penalty': 'l2', 'loss': 'hinge', 'C': 0.02155993553686342}. Best is trial 13 with value: 0.5398571380663335.
# /tmp/ipykernel_46479/1555980142.py:5: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform("C", 1e-3, 1e3)
# /home/sobaqov/anaconda3/lib/python3.11/site-packages/sklearn/svm/_classes.py:31: FutureWarning: The default value of `dual` will change from `True` to `'auto'` in 1.5. Set the value of `dual` explicitly to suppress the warning.
#   warnings.warn(
# /home/sobaqov/anaconda3/lib/python3.11/site-packages/sklearn/svm/_base.py:1237: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# [I 2024-05-12 22:35:33,277] Trial 26 finished with value: 0.5398517922408879 and parameters: {'penalty': 'l2', 'loss': 'hinge', 'C': 0.1441475818079134}. Best is trial 13 with value: 0.5398571380663335.
# /tmp/ipykernel_46479/1555980142.py:5: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform("C", 1e-3, 1e3)
# /home/sobaqov/anaconda3/lib/python3.11/site-packages/sklearn/svm/_classes.py:31: FutureWarning: The default value of `dual` will change from `True` to `'auto'` in 1.5. Set the value of `dual` explicitly to suppress the warning.
#   warnings.warn(
# [I 2024-05-12 22:35:33,713] Trial 27 finished with value: 0.5398517922408879 and parameters: {'penalty': 'l2', 'loss': 'squared_hinge', 'C': 0.5177064774696238}. Best is trial 13 with value: 0.5398571380663335.
# /tmp/ipykernel_46479/1555980142.py:5: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform("C", 1e-3, 1e3)
# /home/sobaqov/anaconda3/lib/python3.11/site-packages/sklearn/svm/_classes.py:31: FutureWarning: The default value of `dual` will change from `True` to `'auto'` in 1.5. Set the value of `dual` explicitly to suppress the warning.
#   warnings.warn(
# /home/sobaqov/anaconda3/lib/python3.11/site-packages/sklearn/svm/_base.py:1237: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# [I 2024-05-12 22:35:34,237] Trial 28 finished with value: 0.5398209315582978 and parameters: {'penalty': 'l2', 'loss': 'hinge', 'C': 0.012842132184220163}. Best is trial 13 with value: 0.5398571380663335.
# /tmp/ipykernel_46479/1555980142.py:5: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform("C", 1e-3, 1e3)
# /home/sobaqov/anaconda3/lib/python3.11/site-packages/sklearn/svm/_classes.py:31: FutureWarning: The default value of `dual` will change from `True` to `'auto'` in 1.5. Set the value of `dual` explicitly to suppress the warning.
#   warnings.warn(
# /home/sobaqov/anaconda3/lib/python3.11/site-packages/sklearn/svm/_base.py:1237: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# [I 2024-05-12 22:35:34,807] Trial 29 finished with value: 0.5398517922408879 and parameters: {'penalty': 'l2', 'loss': 'squared_hinge', 'C': 12.258136132663152}. Best is trial 13 with value: 0.5398571380663335.
# /tmp/ipykernel_46479/1555980142.py:5: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform("C", 1e-3, 1e3)
# /home/sobaqov/anaconda3/lib/python3.11/site-packages/sklearn/svm/_classes.py:31: FutureWarning: The default value of `dual` will change from `True` to `'auto'` in 1.5. Set the value of `dual` explicitly to suppress the warning.
#   warnings.warn(
# [I 2024-05-12 22:35:35,246] Trial 30 finished with value: 0.5398517922408879 and parameters: {'penalty': 'l2', 'loss': 'hinge', 'C': 0.07897290523943262}. Best is trial 13 with value: 0.5398571380663335.
# /tmp/ipykernel_46479/1555980142.py:5: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform("C", 1e-3, 1e3)
# /home/sobaqov/anaconda3/lib/python3.11/site-packages/sklearn/svm/_classes.py:31: FutureWarning: The default value of `dual` will change from `True` to `'auto'` in 1.5. Set the value of `dual` explicitly to suppress the warning.
#   warnings.warn(
# /home/sobaqov/anaconda3/lib/python3.11/site-packages/sklearn/svm/_base.py:1237: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# [I 2024-05-12 22:35:35,830] Trial 31 finished with value: 0.5398336909871244 and parameters: {'penalty': 'l2', 'loss': 'squared_hinge', 'C': 3.89625407666108}. Best is trial 13 with value: 0.5398571380663335.
# /tmp/ipykernel_46479/1555980142.py:5: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform("C", 1e-3, 1e3)
# /home/sobaqov/anaconda3/lib/python3.11/site-packages/sklearn/svm/_classes.py:31: FutureWarning: The default value of `dual` will change from `True` to `'auto'` in 1.5. Set the value of `dual` explicitly to suppress the warning.
#   warnings.warn(
# [I 2024-05-12 22:35:36,274] Trial 32 finished with value: 0.5398517922408879 and parameters: {'penalty': 'l2', 'loss': 'squared_hinge', 'C': 31.48317103001314}. Best is trial 13 with value: 0.5398571380663335.
# /tmp/ipykernel_46479/1555980142.py:5: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform("C", 1e-3, 1e3)
# /home/sobaqov/anaconda3/lib/python3.11/site-packages/sklearn/svm/_classes.py:31: FutureWarning: The default value of `dual` will change from `True` to `'auto'` in 1.5. Set the value of `dual` explicitly to suppress the warning.
#   warnings.warn(
# [I 2024-05-12 22:35:36,710] Trial 33 finished with value: 0.5398517922408879 and parameters: {'penalty': 'l2', 'loss': 'squared_hinge', 'C': 269.5163343745322}. Best is trial 13 with value: 0.5398571380663335.
# /tmp/ipykernel_46479/1555980142.py:5: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform("C", 1e-3, 1e3)
# /home/sobaqov/anaconda3/lib/python3.11/site-packages/sklearn/svm/_classes.py:31: FutureWarning: The default value of `dual` will change from `True` to `'auto'` in 1.5. Set the value of `dual` explicitly to suppress the warning.
#   warnings.warn(
# [I 2024-05-12 22:35:37,139] Trial 34 finished with value: 0.5398517922408879 and parameters: {'penalty': 'l2', 'loss': 'squared_hinge', 'C': 5.318107339533607}. Best is trial 13 with value: 0.5398571380663335.
# /tmp/ipykernel_46479/1555980142.py:5: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform("C", 1e-3, 1e3)
# /home/sobaqov/anaconda3/lib/python3.11/site-packages/sklearn/svm/_classes.py:31: FutureWarning: The default value of `dual` will change from `True` to `'auto'` in 1.5. Set the value of `dual` explicitly to suppress the warning.
#   warnings.warn(
# [I 2024-05-12 22:35:37,623] Trial 35 finished with value: 0.5398517922408879 and parameters: {'penalty': 'l2', 'loss': 'squared_hinge', 'C': 75.91548140914183}. Best is trial 13 with value: 0.5398571380663335.
# /tmp/ipykernel_46479/1555980142.py:5: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform("C", 1e-3, 1e3)
# /home/sobaqov/anaconda3/lib/python3.11/site-packages/sklearn/svm/_classes.py:31: FutureWarning: The default value of `dual` will change from `True` to `'auto'` in 1.5. Set the value of `dual` explicitly to suppress the warning.
#   warnings.warn(
# [I 2024-05-12 22:35:38,063] Trial 36 finished with value: 0.5398517922408879 and parameters: {'penalty': 'l2', 'loss': 'hinge', 'C': 0.5018339571112559}. Best is trial 13 with value: 0.5398571380663335.
# /tmp/ipykernel_46479/1555980142.py:5: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform("C", 1e-3, 1e3)
# /home/sobaqov/anaconda3/lib/python3.11/site-packages/sklearn/svm/_classes.py:31: FutureWarning: The default value of `dual` will change from `True` to `'auto'` in 1.5. Set the value of `dual` explicitly to suppress the warning.
#   warnings.warn(
# [I 2024-05-12 22:35:38,507] Trial 37 finished with value: 0.5398517922408879 and parameters: {'penalty': 'l2', 'loss': 'hinge', 'C': 0.006627880804984552}. Best is trial 13 with value: 0.5398571380663335.
# /tmp/ipykernel_46479/1555980142.py:5: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform("C", 1e-3, 1e3)
# /home/sobaqov/anaconda3/lib/python3.11/site-packages/sklearn/svm/_classes.py:31: FutureWarning: The default value of `dual` will change from `True` to `'auto'` in 1.5. Set the value of `dual` explicitly to suppress the warning.
#   warnings.warn(
# [I 2024-05-12 22:35:38,939] Trial 38 finished with value: 0.5398517922408879 and parameters: {'penalty': 'l2', 'loss': 'squared_hinge', 'C': 20.491805883976443}. Best is trial 13 with value: 0.5398571380663335.
# /tmp/ipykernel_46479/1555980142.py:5: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform("C", 1e-3, 1e3)
# /home/sobaqov/anaconda3/lib/python3.11/site-packages/sklearn/svm/_classes.py:31: FutureWarning: The default value of `dual` will change from `True` to `'auto'` in 1.5. Set the value of `dual` explicitly to suppress the warning.
#   warnings.warn(
# /home/sobaqov/anaconda3/lib/python3.11/site-packages/sklearn/svm/_base.py:1237: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# [I 2024-05-12 22:35:39,464] Trial 39 finished with value: 0.5398336909871244 and parameters: {'penalty': 'l2', 'loss': 'hinge', 'C': 0.001823550936708682}. Best is trial 13 with value: 0.5398571380663335.
# /tmp/ipykernel_46479/1555980142.py:5: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform("C", 1e-3, 1e3)
# /home/sobaqov/anaconda3/lib/python3.11/site-packages/sklearn/svm/_classes.py:31: FutureWarning: The default value of `dual` will change from `True` to `'auto'` in 1.5. Set the value of `dual` explicitly to suppress the warning.
#   warnings.warn(
# /home/sobaqov/anaconda3/lib/python3.11/site-packages/sklearn/svm/_base.py:1237: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# [I 2024-05-12 22:35:39,990] Trial 40 finished with value: 0.5398517922408879 and parameters: {'penalty': 'l2', 'loss': 'squared_hinge', 'C': 1.8627136885651034}. Best is trial 13 with value: 0.5398571380663335.
# /tmp/ipykernel_46479/1555980142.py:5: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform("C", 1e-3, 1e3)
# /home/sobaqov/anaconda3/lib/python3.11/site-packages/sklearn/svm/_classes.py:31: FutureWarning: The default value of `dual` will change from `True` to `'auto'` in 1.5. Set the value of `dual` explicitly to suppress the warning.
#   warnings.warn(
# /home/sobaqov/anaconda3/lib/python3.11/site-packages/sklearn/svm/_base.py:1237: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# [I 2024-05-12 22:35:40,518] Trial 41 finished with value: 0.5398517922408879 and parameters: {'penalty': 'l2', 'loss': 'hinge', 'C': 7.5659587206575845}. Best is trial 13 with value: 0.5398571380663335.
# /tmp/ipykernel_46479/1555980142.py:5: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform("C", 1e-3, 1e3)
# /home/sobaqov/anaconda3/lib/python3.11/site-packages/sklearn/svm/_classes.py:31: FutureWarning: The default value of `dual` will change from `True` to `'auto'` in 1.5. Set the value of `dual` explicitly to suppress the warning.
#   warnings.warn(
# /home/sobaqov/anaconda3/lib/python3.11/site-packages/sklearn/svm/_base.py:1237: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# [I 2024-05-12 22:35:41,045] Trial 42 finished with value: 0.5398517922408879 and parameters: {'penalty': 'l2', 'loss': 'hinge', 'C': 1.8225087750395468}. Best is trial 13 with value: 0.5398571380663335.
# /tmp/ipykernel_46479/1555980142.py:5: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform("C", 1e-3, 1e3)
# /home/sobaqov/anaconda3/lib/python3.11/site-packages/sklearn/svm/_classes.py:31: FutureWarning: The default value of `dual` will change from `True` to `'auto'` in 1.5. Set the value of `dual` explicitly to suppress the warning.
#   warnings.warn(
# [I 2024-05-12 22:35:41,480] Trial 43 finished with value: 0.5398517922408879 and parameters: {'penalty': 'l2', 'loss': 'hinge', 'C': 100.22575134838887}. Best is trial 13 with value: 0.5398571380663335.
# /tmp/ipykernel_46479/1555980142.py:5: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform("C", 1e-3, 1e3)
# /home/sobaqov/anaconda3/lib/python3.11/site-packages/sklearn/svm/_classes.py:31: FutureWarning: The default value of `dual` will change from `True` to `'auto'` in 1.5. Set the value of `dual` explicitly to suppress the warning.
#   warnings.warn(
# [I 2024-05-12 22:35:41,913] Trial 44 finished with value: 0.5398517922408879 and parameters: {'penalty': 'l2', 'loss': 'hinge', 'C': 32.26218386031343}. Best is trial 13 with value: 0.5398571380663335.
# /tmp/ipykernel_46479/1555980142.py:5: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform("C", 1e-3, 1e3)
# /home/sobaqov/anaconda3/lib/python3.11/site-packages/sklearn/svm/_classes.py:31: FutureWarning: The default value of `dual` will change from `True` to `'auto'` in 1.5. Set the value of `dual` explicitly to suppress the warning.
#   warnings.warn(
# /home/sobaqov/anaconda3/lib/python3.11/site-packages/sklearn/svm/_base.py:1237: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# [I 2024-05-12 22:35:42,460] Trial 45 finished with value: 0.5398517922408879 and parameters: {'penalty': 'l2', 'loss': 'hinge', 'C': 0.03497444424023321}. Best is trial 13 with value: 0.5398571380663335.
# /tmp/ipykernel_46479/1555980142.py:5: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform("C", 1e-3, 1e3)
# /home/sobaqov/anaconda3/lib/python3.11/site-packages/sklearn/svm/_classes.py:31: FutureWarning: The default value of `dual` will change from `True` to `'auto'` in 1.5. Set the value of `dual` explicitly to suppress the warning.
#   warnings.warn(
# [I 2024-05-12 22:35:42,893] Trial 46 finished with value: 0.5398517922408879 and parameters: {'penalty': 'l2', 'loss': 'hinge', 'C': 931.0781676372059}. Best is trial 13 with value: 0.5398571380663335.
# /tmp/ipykernel_46479/1555980142.py:5: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform("C", 1e-3, 1e3)
# /home/sobaqov/anaconda3/lib/python3.11/site-packages/sklearn/svm/_classes.py:31: FutureWarning: The default value of `dual` will change from `True` to `'auto'` in 1.5. Set the value of `dual` explicitly to suppress the warning.
#   warnings.warn(
# [I 2024-05-12 22:35:43,331] Trial 47 finished with value: 0.5398517922408879 and parameters: {'penalty': 'l2', 'loss': 'hinge', 'C': 0.8222893064353576}. Best is trial 13 with value: 0.5398571380663335.
# /tmp/ipykernel_46479/1555980142.py:5: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform("C", 1e-3, 1e3)
# /home/sobaqov/anaconda3/lib/python3.11/site-packages/sklearn/svm/_classes.py:31: FutureWarning: The default value of `dual` will change from `True` to `'auto'` in 1.5. Set the value of `dual` explicitly to suppress the warning.
#   warnings.warn(
# [I 2024-05-12 22:35:43,778] Trial 48 finished with value: 0.5398517922408879 and parameters: {'penalty': 'l2', 'loss': 'hinge', 'C': 0.003565011089091192}. Best is trial 13 with value: 0.5398571380663335.
# /tmp/ipykernel_46479/1555980142.py:5: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform("C", 1e-3, 1e3)
# /home/sobaqov/anaconda3/lib/python3.11/site-packages/sklearn/svm/_classes.py:31: FutureWarning: The default value of `dual` will change from `True` to `'auto'` in 1.5. Set the value of `dual` explicitly to suppress the warning.
#   warnings.warn(
# [I 2024-05-12 22:35:44,211] Trial 49 finished with value: 0.5398517922408879 and parameters: {'penalty': 'l2', 'loss': 'hinge', 'C': 3.4920283085692536}. Best is trial 13 with value: 0.5398571380663335.
# /tmp/ipykernel_46479/1555980142.py:5: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform("C", 1e-3, 1e3)
# /home/sobaqov/anaconda3/lib/python3.11/site-packages/sklearn/svm/_classes.py:31: FutureWarning: The default value of `dual` will change from `True` to `'auto'` in 1.5. Set the value of `dual` explicitly to suppress the warning.
#   warnings.warn(
# [I 2024-05-12 22:35:44,648] Trial 50 finished with value: 0.5398517922408879 and parameters: {'penalty': 'l2', 'loss': 'squared_hinge', 'C': 0.010177228235187893}. Best is trial 13 with value: 0.5398571380663335.
# /tmp/ipykernel_46479/1555980142.py:5: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform("C", 1e-3, 1e3)
# /home/sobaqov/anaconda3/lib/python3.11/site-packages/sklearn/svm/_classes.py:31: FutureWarning: The default value of `dual` will change from `True` to `'auto'` in 1.5. Set the value of `dual` explicitly to suppress the warning.
#   warnings.warn(
# [I 2024-05-12 22:35:45,129] Trial 51 finished with value: 0.5398517922408879 and parameters: {'penalty': 'l2', 'loss': 'squared_hinge', 'C': 0.0010726952897054938}. Best is trial 13 with value: 0.5398571380663335.
# /tmp/ipykernel_46479/1555980142.py:5: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform("C", 1e-3, 1e3)
# /home/sobaqov/anaconda3/lib/python3.11/site-packages/sklearn/svm/_classes.py:31: FutureWarning: The default value of `dual` will change from `True` to `'auto'` in 1.5. Set the value of `dual` explicitly to suppress the warning.
#   warnings.warn(
# [I 2024-05-12 22:35:45,584] Trial 52 finished with value: 0.5398517922408879 and parameters: {'penalty': 'l2', 'loss': 'squared_hinge', 'C': 0.026036970936485136}. Best is trial 13 with value: 0.5398571380663335.
# /tmp/ipykernel_46479/1555980142.py:5: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform("C", 1e-3, 1e3)
# /home/sobaqov/anaconda3/lib/python3.11/site-packages/sklearn/svm/_classes.py:31: FutureWarning: The default value of `dual` will change from `True` to `'auto'` in 1.5. Set the value of `dual` explicitly to suppress the warning.
#   warnings.warn(
# [I 2024-05-12 22:35:46,012] Trial 53 finished with value: 0.5398517922408879 and parameters: {'penalty': 'l2', 'loss': 'squared_hinge', 'C': 0.004920371603210376}. Best is trial 13 with value: 0.5398571380663335.
# /tmp/ipykernel_46479/1555980142.py:5: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform("C", 1e-3, 1e3)
# /home/sobaqov/anaconda3/lib/python3.11/site-packages/sklearn/svm/_classes.py:31: FutureWarning: The default value of `dual` will change from `True` to `'auto'` in 1.5. Set the value of `dual` explicitly to suppress the warning.
#   warnings.warn(
# [I 2024-05-12 22:35:46,452] Trial 54 finished with value: 0.5398517922408879 and parameters: {'penalty': 'l2', 'loss': 'squared_hinge', 'C': 0.07873671665846915}. Best is trial 13 with value: 0.5398571380663335.
# /tmp/ipykernel_46479/1555980142.py:5: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform("C", 1e-3, 1e3)
# /home/sobaqov/anaconda3/lib/python3.11/site-packages/sklearn/svm/_classes.py:31: FutureWarning: The default value of `dual` will change from `True` to `'auto'` in 1.5. Set the value of `dual` explicitly to suppress the warning.
#   warnings.warn(
# [I 2024-05-12 22:35:46,880] Trial 55 finished with value: 0.5398517922408879 and parameters: {'penalty': 'l2', 'loss': 'hinge', 'C': 0.003011901094291159}. Best is trial 13 with value: 0.5398571380663335.
# /tmp/ipykernel_46479/1555980142.py:5: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform("C", 1e-3, 1e3)
# /home/sobaqov/anaconda3/lib/python3.11/site-packages/sklearn/svm/_classes.py:31: FutureWarning: The default value of `dual` will change from `True` to `'auto'` in 1.5. Set the value of `dual` explicitly to suppress the warning.
#   warnings.warn(
# [I 2024-05-12 22:35:47,310] Trial 56 finished with value: 0.5398517922408879 and parameters: {'penalty': 'l2', 'loss': 'hinge', 'C': 0.007501882827947921}. Best is trial 13 with value: 0.5398571380663335.
# /tmp/ipykernel_46479/1555980142.py:5: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform("C", 1e-3, 1e3)
# /home/sobaqov/anaconda3/lib/python3.11/site-packages/sklearn/svm/_classes.py:31: FutureWarning: The default value of `dual` will change from `True` to `'auto'` in 1.5. Set the value of `dual` explicitly to suppress the warning.
#   warnings.warn(
# [I 2024-05-12 22:35:47,738] Trial 57 finished with value: 0.5398517922408879 and parameters: {'penalty': 'l2', 'loss': 'hinge', 'C': 0.002195413439005107}. Best is trial 13 with value: 0.5398571380663335.
# /tmp/ipykernel_46479/1555980142.py:5: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform("C", 1e-3, 1e3)
# /home/sobaqov/anaconda3/lib/python3.11/site-packages/sklearn/svm/_classes.py:31: FutureWarning: The default value of `dual` will change from `True` to `'auto'` in 1.5. Set the value of `dual` explicitly to suppress the warning.
#   warnings.warn(
# [I 2024-05-12 22:35:48,220] Trial 58 finished with value: 0.5398517922408879 and parameters: {'penalty': 'l2', 'loss': 'squared_hinge', 'C': 0.3619940446574315}. Best is trial 13 with value: 0.5398571380663335.
# /tmp/ipykernel_46479/1555980142.py:5: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform("C", 1e-3, 1e3)
# /home/sobaqov/anaconda3/lib/python3.11/site-packages/sklearn/svm/_classes.py:31: FutureWarning: The default value of `dual` will change from `True` to `'auto'` in 1.5. Set the value of `dual` explicitly to suppress the warning.
#   warnings.warn(
# [I 2024-05-12 22:35:48,690] Trial 59 finished with value: 0.5398517922408879 and parameters: {'penalty': 'l2', 'loss': 'hinge', 'C': 0.012432127059225546}. Best is trial 13 with value: 0.5398571380663335.
# /tmp/ipykernel_46479/1555980142.py:5: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform("C", 1e-3, 1e3)
# ...
#   C = trial.suggest_loguniform("C", 1e-3, 1e3)
# /home/sobaqov/anaconda3/lib/python3.11/site-packages/sklearn/svm/_classes.py:31: FutureWarning: The default value of `dual` will change from `True` to `'auto'` in 1.5. Set the value of `dual` explicitly to suppress the warning.
#   warnings.warn(
# /home/sobaqov/anaconda3/lib/python3.11/site-packages/sklearn/svm/_base.py:1237: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# [I 2024-05-12 22:35:58,475] Trial 80 finished with value: 0.5398698947086044 and parameters: {'penalty': 'l2', 'loss': 'hinge', 'C': 1.1813969402514557}. Best is trial 80 with value: 0.5398698947086044.
# /tmp/ipykernel_46479/1555980142.py:5: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform("C", 1e-3, 1e3)
# /home/sobaqov/anaconda3/lib/python3.11/site-packages/sklearn/svm/_classes.py:31: FutureWarning: The default value of `dual` will change from `True` to `'auto'` in 1.5. Set the value of `dual` explicitly to suppress the warning.
#   warnings.warn(
# [I 2024-05-12 22:35:58,907] Trial 81 finished with value: 0.5398517922408879 and parameters: {'penalty': 'l2', 'loss': 'hinge', 'C': 4.135831765502741}. Best is trial 80 with value: 0.5398698947086044.
# /tmp/ipykernel_46479/1555980142.py:5: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform("C", 1e-3, 1e3)
# /home/sobaqov/anaconda3/lib/python3.11/site-packages/sklearn/svm/_classes.py:31: FutureWarning: The default value of `dual` will change from `True` to `'auto'` in 1.5. Set the value of `dual` explicitly to suppress the warning.
#   warnings.warn(
# [I 2024-05-12 22:35:59,377] Trial 82 finished with value: 0.5398517922408879 and parameters: {'penalty': 'l2', 'loss': 'hinge', 'C': 1.196253672819283}. Best is trial 80 with value: 0.5398698947086044.
# /tmp/ipykernel_46479/1555980142.py:5: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform("C", 1e-3, 1e3)
# /home/sobaqov/anaconda3/lib/python3.11/site-packages/sklearn/svm/_classes.py:31: FutureWarning: The default value of `dual` will change from `True` to `'auto'` in 1.5. Set the value of `dual` explicitly to suppress the warning.
#   warnings.warn(
# /home/sobaqov/anaconda3/lib/python3.11/site-packages/sklearn/svm/_base.py:1237: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# [I 2024-05-12 22:35:59,903] Trial 83 finished with value: 0.5398517922408879 and parameters: {'penalty': 'l2', 'loss': 'hinge', 'C': 0.0028246356606900533}. Best is trial 80 with value: 0.5398698947086044.
# /tmp/ipykernel_46479/1555980142.py:5: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform("C", 1e-3, 1e3)
# /home/sobaqov/anaconda3/lib/python3.11/site-packages/sklearn/svm/_classes.py:31: FutureWarning: The default value of `dual` will change from `True` to `'auto'` in 1.5. Set the value of `dual` explicitly to suppress the warning.
#   warnings.warn(
# [I 2024-05-12 22:36:00,340] Trial 84 finished with value: 0.5398517922408879 and parameters: {'penalty': 'l2', 'loss': 'hinge', 'C': 0.6856929044976303}. Best is trial 80 with value: 0.5398698947086044.
# /tmp/ipykernel_46479/1555980142.py:5: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform("C", 1e-3, 1e3)
# /home/sobaqov/anaconda3/lib/python3.11/site-packages/sklearn/svm/_classes.py:31: FutureWarning: The default value of `dual` will change from `True` to `'auto'` in 1.5. Set the value of `dual` explicitly to suppress the warning.
#   warnings.warn(
# /home/sobaqov/anaconda3/lib/python3.11/site-packages/sklearn/svm/_base.py:1237: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# [I 2024-05-12 22:36:00,857] Trial 85 finished with value: 0.5398336909871244 and parameters: {'penalty': 'l2', 'loss': 'squared_hinge', 'C': 0.3001100176697021}. Best is trial 80 with value: 0.5398698947086044.
# /tmp/ipykernel_46479/1555980142.py:5: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform("C", 1e-3, 1e3)
# /home/sobaqov/anaconda3/lib/python3.11/site-packages/sklearn/svm/_classes.py:31: FutureWarning: The default value of `dual` will change from `True` to `'auto'` in 1.5. Set the value of `dual` explicitly to suppress the warning.
#   warnings.warn(
# /home/sobaqov/anaconda3/lib/python3.11/site-packages/sklearn/svm/_base.py:1237: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# [I 2024-05-12 22:36:01,431] Trial 86 finished with value: 0.5400476078720622 and parameters: {'penalty': 'l2', 'loss': 'hinge', 'C': 0.03258763709052359}. Best is trial 86 with value: 0.5400476078720622.
# /tmp/ipykernel_46479/1555980142.py:5: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform("C", 1e-3, 1e3)
# /home/sobaqov/anaconda3/lib/python3.11/site-packages/sklearn/svm/_classes.py:31: FutureWarning: The default value of `dual` will change from `True` to `'auto'` in 1.5. Set the value of `dual` explicitly to suppress the warning.
#   warnings.warn(
# /home/sobaqov/anaconda3/lib/python3.11/site-packages/sklearn/svm/_base.py:1237: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# [I 2024-05-12 22:36:01,973] Trial 87 finished with value: 0.5398336909871244 and parameters: {'penalty': 'l2', 'loss': 'hinge', 'C': 0.02140927753993958}. Best is trial 86 with value: 0.5400476078720622.
# /tmp/ipykernel_46479/1555980142.py:5: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform("C", 1e-3, 1e3)
# /home/sobaqov/anaconda3/lib/python3.11/site-packages/sklearn/svm/_classes.py:31: FutureWarning: The default value of `dual` will change from `True` to `'auto'` in 1.5. Set the value of `dual` explicitly to suppress the warning.
#   warnings.warn(
# [I 2024-05-12 22:36:02,403] Trial 88 finished with value: 0.5398517922408879 and parameters: {'penalty': 'l2', 'loss': 'hinge', 'C': 0.03673591028694803}. Best is trial 86 with value: 0.5400476078720622.
# /tmp/ipykernel_46479/1555980142.py:5: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform("C", 1e-3, 1e3)
# /home/sobaqov/anaconda3/lib/python3.11/site-packages/sklearn/svm/_classes.py:31: FutureWarning: The default value of `dual` will change from `True` to `'auto'` in 1.5. Set the value of `dual` explicitly to suppress the warning.
#   warnings.warn(
# [I 2024-05-12 22:36:02,826] Trial 89 finished with value: 0.5398517922408879 and parameters: {'penalty': 'l2', 'loss': 'squared_hinge', 'C': 1.330772767521692}. Best is trial 86 with value: 0.5400476078720622.
# /tmp/ipykernel_46479/1555980142.py:5: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform("C", 1e-3, 1e3)
# /home/sobaqov/anaconda3/lib/python3.11/site-packages/sklearn/svm/_classes.py:31: FutureWarning: The default value of `dual` will change from `True` to `'auto'` in 1.5. Set the value of `dual` explicitly to suppress the warning.
#   warnings.warn(
# [I 2024-05-12 22:36:03,262] Trial 90 finished with value: 0.5398517922408879 and parameters: {'penalty': 'l2', 'loss': 'hinge', 'C': 0.015141815101268448}. Best is trial 86 with value: 0.5400476078720622.
# /tmp/ipykernel_46479/1555980142.py:5: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform("C", 1e-3, 1e3)
# /home/sobaqov/anaconda3/lib/python3.11/site-packages/sklearn/svm/_classes.py:31: FutureWarning: The default value of `dual` will change from `True` to `'auto'` in 1.5. Set the value of `dual` explicitly to suppress the warning.
#   warnings.warn(
# [I 2024-05-12 22:36:03,694] Trial 91 finished with value: 0.5398517922408879 and parameters: {'penalty': 'l2', 'loss': 'hinge', 'C': 0.07478568084544206}. Best is trial 86 with value: 0.5400476078720622.
# /tmp/ipykernel_46479/1555980142.py:5: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform("C", 1e-3, 1e3)
# /home/sobaqov/anaconda3/lib/python3.11/site-packages/sklearn/svm/_classes.py:31: FutureWarning: The default value of `dual` will change from `True` to `'auto'` in 1.5. Set the value of `dual` explicitly to suppress the warning.
#   warnings.warn(
# [I 2024-05-12 22:36:04,125] Trial 92 finished with value: 0.5398517922408879 and parameters: {'penalty': 'l2', 'loss': 'hinge', 'C': 0.006027926446188817}. Best is trial 86 with value: 0.5400476078720622.
# /tmp/ipykernel_46479/1555980142.py:5: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform("C", 1e-3, 1e3)
# /home/sobaqov/anaconda3/lib/python3.11/site-packages/sklearn/svm/_classes.py:31: FutureWarning: The default value of `dual` will change from `True` to `'auto'` in 1.5. Set the value of `dual` explicitly to suppress the warning.
#   warnings.warn(
# [I 2024-05-12 22:36:04,561] Trial 93 finished with value: 0.5398517922408879 and parameters: {'penalty': 'l2', 'loss': 'hinge', 'C': 0.1798603243732589}. Best is trial 86 with value: 0.5400476078720622.
# /tmp/ipykernel_46479/1555980142.py:5: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform("C", 1e-3, 1e3)
# /home/sobaqov/anaconda3/lib/python3.11/site-packages/sklearn/svm/_classes.py:31: FutureWarning: The default value of `dual` will change from `True` to `'auto'` in 1.5. Set the value of `dual` explicitly to suppress the warning.
#   warnings.warn(
# [I 2024-05-12 22:36:05,029] Trial 94 finished with value: 0.5398517922408879 and parameters: {'penalty': 'l2', 'loss': 'hinge', 'C': 0.009810412094029526}. Best is trial 86 with value: 0.5400476078720622.
# /tmp/ipykernel_46479/1555980142.py:5: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform("C", 1e-3, 1e3)
# /home/sobaqov/anaconda3/lib/python3.11/site-packages/sklearn/svm/_classes.py:31: FutureWarning: The default value of `dual` will change from `True` to `'auto'` in 1.5. Set the value of `dual` explicitly to suppress the warning.
#   warnings.warn(
# [I 2024-05-12 22:36:05,473] Trial 95 finished with value: 0.5398517922408879 and parameters: {'penalty': 'l2', 'loss': 'hinge', 'C': 0.02777958147710671}. Best is trial 86 with value: 0.5400476078720622.
# /tmp/ipykernel_46479/1555980142.py:5: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform("C", 1e-3, 1e3)
# /home/sobaqov/anaconda3/lib/python3.11/site-packages/sklearn/svm/_classes.py:31: FutureWarning: The default value of `dual` will change from `True` to `'auto'` in 1.5. Set the value of `dual` explicitly to suppress the warning.
#   warnings.warn(
# [I 2024-05-12 22:36:05,950] Trial 96 finished with value: 0.5398517922408879 and parameters: {'penalty': 'l2', 'loss': 'squared_hinge', 'C': 140.38772132656354}. Best is trial 86 with value: 0.5400476078720622.
# /tmp/ipykernel_46479/1555980142.py:5: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform("C", 1e-3, 1e3)
# /home/sobaqov/anaconda3/lib/python3.11/site-packages/sklearn/svm/_classes.py:31: FutureWarning: The default value of `dual` will change from `True` to `'auto'` in 1.5. Set the value of `dual` explicitly to suppress the warning.
#   warnings.warn(
# [I 2024-05-12 22:36:06,414] Trial 97 finished with value: 0.5398517922408879 and parameters: {'penalty': 'l2', 'loss': 'hinge', 'C': 0.4049757906337944}. Best is trial 86 with value: 0.5400476078720622.
# /tmp/ipykernel_46479/1555980142.py:5: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform("C", 1e-3, 1e3)
# /home/sobaqov/anaconda3/lib/python3.11/site-packages/sklearn/svm/_classes.py:31: FutureWarning: The default value of `dual` will change from `True` to `'auto'` in 1.5. Set the value of `dual` explicitly to suppress the warning.
#   warnings.warn(
# [I 2024-05-12 22:36:06,855] Trial 98 finished with value: 0.5398517922408879 and parameters: {'penalty': 'l2', 'loss': 'hinge', 'C': 2.35811842345049}. Best is trial 86 with value: 0.5400476078720622.
# /tmp/ipykernel_46479/1555980142.py:5: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform("C", 1e-3, 1e3)
# /home/sobaqov/anaconda3/lib/python3.11/site-packages/sklearn/svm/_classes.py:31: FutureWarning: The default value of `dual` will change from `True` to `'auto'` in 1.5. Set the value of `dual` explicitly to suppress the warning.
#   warnings.warn(
# /home/sobaqov/anaconda3/lib/python3.11/site-packages/sklearn/svm/_base.py:1237: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# [I 2024-05-12 22:36:07,379] Trial 99 finished with value: 0.5398517922408879 and parameters: {'penalty': 'l2', 'loss': 'hinge', 'C': 0.12321038575114057}. Best is trial 86 with value: 0.5400476078720622.
# Best parameters:  {'penalty': 'l2', 'loss': 'hinge', 'C': 0.03258763709052359}
# Best model:  LinearSVC(C=0.03258763709052359, loss='hinge')

# %% [markdown]
# ## Prediction

# %%
best_model.fit(X_train, y_train)
y_pred = best_model.predict(df_test_pca)
y_pred_df = pd.DataFrame(y_pred, columns=['failure'])
# Out:
# /home/sobaqov/anaconda3/lib/python3.11/site-packages/sklearn/svm/_classes.py:31: FutureWarning: The default value of `dual` will change from `True` to `'auto'` in 1.5. Set the value of `dual` explicitly to suppress the warning.
#   warnings.warn(
# /home/sobaqov/anaconda3/lib/python3.11/site-packages/sklearn/svm/_base.py:1237: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(

# %%
y_submission = pd.concat([df_test_id, y_pred_df], axis=1)

# %%
y_submission.head()
# Out:
#       id  failure
# 0  26570      0.0
# 1  26571      0.0
# 2  26572      0.0
# 3  26573      0.0
# 4  26574      1.0

# %%
y_submission.to_csv('./../Submission/kid_submission_linearsvc_v3.csv', index=False)
